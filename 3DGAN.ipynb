# %% [markdown]
# <a href="https://colab.research.google.com/github/ashishpatel26/simple-pytorch-3dgan/blob/master/3DGAN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Download 3D model data

# %%
import os
os.system('wget http://3dshapenets.cs.princeton.edu/3DShapeNetsCode.zip')
# Out:
# 0

# %% [markdown]
# ### Unpack the Zip file

# %%
import shutil
shutil.unpack_archive("/content/3DShapeNetsCode.zip")

# %%
# !git clone https://github.com/ashishpatel26/simple-pytorch-3dgan.git
# Out:
# Cloning into 'simple-pytorch-3dgan'...
# remote: Enumerating objects: 10778, done.
# remote: Total 10778 (delta 0), reused 0 (delta 0), pack-reused 10778
# Receiving objects: 100% (10778/10778), 40.62 MiB | 23.69 MiB/s, done.
# Resolving deltas: 100% (75/75), done.

# %%
# %cd /content/simple-pytorch-3dgan/src
# Out:
# /content/simple-pytorch-3dgan/src

# %%
# !ls
# Out:
# main.py  model.py  params.py  tester.py  trainer.py  utils.py

# %%
# !pip install tensorboardX visdom
# Out:
# ...
#      |████████████████████████████████| 686kB 11.0MB/s
# ...
#      |████████████████████████████████| 71kB 8.0MB/s
# ...
#   Created wheel for visdom: filename=visdom-0.1.8.9-cp37-none-any.whl size=655251 sha256=4bd8021507fdc6b15feb1333e3a14880a25a52072d66872a379b287279032919
#   Stored in directory: /root/.cache/pip/wheels/70/19/a7/6d589ed967f4dfefd33bc166d081257bd4ed0cb618dccfd62a
# ...
#   Created wheel for torchfile: filename=torchfile-0.1.0-cp37-none-any.whl size=5712 sha256=b5cd412c30361ef74a14a66b3fbf58c29a8014ac30af26ba6ce0df9d60468c0e
#   Stored in directory: /root/.cache/pip/wheels/b1/c3/d6/9a1cc8f3a99a0fc1124cae20153f36af59a6e683daca0a0814
# Successfully built visdom torchfile
# ...

# %%
# !python main.py
# Out:
# ****************hyper-parameters****************
# epochs = 500
# batch_size = 32
# soft_labels = False
# adv_weight = 0
# d_thresh = 0.8
# z_dim = 200
# z_dis = norm
# model_images_save_step = 1
# data = chair/
# device = cuda
# g_lr = 0.0025
# d_lr = 1e-05
# cube_len = 32
# leak_value = 0.2
# bias = False
# ****************hyper-parameters****************
# ../outputs/dcgan
# ../volumetric_data/chair/30/train/
# data_size = 10668
# 100% 334/334 [01:43<00:00,  3.22it/s]
# Epochs-0 (train) , D(x) : 2.491, D(G(x)) : 0.2302
# Elapsed Time: 1.728 min
# model_saved, images_saved...
# 100% 334/334 [01:40<00:00,  3.32it/s]
# Epochs-1 (train) , D(x) : 1.572, D(G(x)) : 0.5883
# Elapsed Time: 1.675 min
# model_saved, images_saved...
# 100% 334/334 [01:41<00:00,  3.30it/s]
# Epochs-2 (train) , D(x) : 1.445, D(G(x)) : 0.7072
# Elapsed Time: 1.687 min
# model_saved, images_saved...
# 100% 334/334 [01:41<00:00,  3.30it/s]
# Epochs-3 (train) , D(x) : 1.4, D(G(x)) : 0.7441
# ...
